# %%
import pandas as pd

# %%
df = pd.read_csv("x_scraper_results_20251111_201339.csv")
df.head(20)
# Out:
#    author_affiliatesHighlightedLabel  author_automatedBy author_canDm  \
# 0                                 {}                 NaN         True
# 1                                 {}                 NaN        False
# 2                                 {}                 NaN         True
# 3                                 {}                 NaN         True
# 4                                 {}                 NaN         True
# 5                                 {}                 NaN         True
# 6                                 {}                 NaN         True
# 7                                 {}                 NaN        False
# 8                                 {}                 NaN         True
# 9                                 {}                 NaN         True
# 10                                {}                 NaN         True
# 11                                {}                 NaN        False
# ...
